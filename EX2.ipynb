# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\HDC0422094\Downloads\housing_dataset.xlsx',sheet_name='housing_dataset')

# %%
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000        NaN         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
rows_before = df.shape[0]
df.dropna(inplace=True)
rows_after = df.shape[0]
print(f'Rows before dropping: {rows_before}')
print(f'Rows after dropping: {rows_after}')
# Out:
# Rows before dropping: 1000
# Rows after dropping: 797

# %%
null_columns = df.columns[df.isnull().any()].tolist()
print(f'Columns with null values: {null_columns}')
# Out:
# Columns with null values: ['Price', 'Bathrooms', 'Sqft_Living', 'Sqft_Lot']

# %%
cleaned_file_path = 'cleaned_data.xlsx'
df.to_excel(cleaned_file_path, index=False)

print(f'Data cleaning complete. The cleaned file is saved as {cleaned_file_path}.')
# Out:
# Data cleaning complete. The cleaned file is saved as cleaned_data.xlsx.
